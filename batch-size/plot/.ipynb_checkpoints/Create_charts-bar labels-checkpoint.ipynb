# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
names= ['DBMS-NonML',
        'SQLRE-DT','SQLRE-RF','SQLRE-XGB','SQLRE-Ridge','SQLRE-DNN',
        'QBML-DT','QBML-RF','QBML-XGB','QBML-Ridge','QBML-DNN']

# %%
bar_colors = np.random.rand(len(names),3)

# %% [markdown]
# # RMSE

# %% [markdown]
# ## TPC-DS

# %%
data = pd.read_excel('data.xlsx')

# %%
column = 'A'
# data = data.sort_values(column).reset_index(drop=True)
names = data['models']
values = data[column]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xticks(rotation='vertical')

for i in range(0, len(names)):
    plt.barh(names[i], values[i], color=bar_colors[i])
#plt.title("JOB RMSE Error")
plt.ylabel("Model")
plt.xlabel("RMSE Error (MB)")
# fig.subplots_adjust(bottom=.5)
#plt.legend(names, loc=0, frameon=True)
fig.savefig('TPCDS-RMSE Error.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
column = 'A'
# data = data.sort_values(column).reset_index(drop=True)
names = data['models']
values = data[column]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xticks(rotation='vertical')

for i in range(0, len(names)):
    plt.barh(names[i], values[i], color=bar_colors[i])
#plt.title("JOB RMSE Error")
plt.ylabel("Model")
plt.xlabel("RMSE Error (MB)")
# fig.subplots_adjust(bottom=.5)
#plt.legend(names, loc=0, frameon=True)
fig.savefig('TPCDS-RMSE Error.png', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ## JOB

# %%
data = pd.read_excel('data_job.xlsx')

column = 'A'
# data = data.sort_values(column).reset_index(drop=True)
names = data['models']
values = data[column]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

plt.xticks(rotation='vertical')

for i in range(0, len(names)):
    plt.barh(names[i], values[i], color=bar_colors[i])
#plt.title("JOB RMSE Error")
plt.ylabel("Model")
plt.xlabel("RMSE Error (MB)")
# fig.subplots_adjust(bottom=.5)
#plt.legend(names, loc=0, frameon=True)
fig.savefig('JOB-RMSE Error.png', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# # Training Latency

# %% [markdown]
# ## TPC-DS

# %%
data2 = pd.read_excel('book2.xlsx')

# %%
column = 'B'
# data2 = data2.sort_values(column).reset_index(drop=True)
names = data2['models']
values = data2[column]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xticks(rotation='vertical')

for i in range(0, len(names)):
    plt.barh(names[i], values[i], color=bar_colors[i])
#plt.title("TPCDS Training Time")
plt.ylabel("Model")
plt.xlabel("Training Time(ms)")
# fig.subplots_adjust(bottom=.5)
#plt.legend(names, loc=0, frameon=True)
fig.savefig('TPCDS-Training Time.png', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ## JOB

# %%
data2 = pd.read_excel('data_job2.xlsx')

# %%
column = 'B'
# data2 = data2.sort_values(column).reset_index(drop=True)
names = data2['models']
values = data2[column]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xticks(rotation='vertical')

for i in range(0, len(names)):
    plt.barh(names[i], values[i], color=bar_colors[i])
#plt.title("JOB Training Time")
plt.ylabel("Model")
plt.xlabel("Training Time(ms)")
# fig.subplots_adjust(bottom=.5)
#plt.legend(names, loc=0, frameon=True)
fig.savefig('JOB-Training Time.png', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# # Inference Latency

# %% [markdown]
# ## TPC-DS

# %%
data2 = pd.read_excel('book2.xlsx')

# %%
column = 'C'
# data2 = data2.sort_values(column).reset_index(drop=True)
names = data2['models']
values = data2[column]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xticks(rotation='vertical')

for i in range(0, len(names)):
    plt.barh(names[i], values[i], color=bar_colors[i])
#plt.title("TPCDS Inference Time")
plt.ylabel("Model")
plt.xlabel("Inference Time (μs)")
# fig.subplots_adjust(bottom=.5)
#plt.legend(names, loc=0, frameon=True)
fig.savefig('TPCDS-Inference Time.png', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# # JOB

# %%
data2 = pd.read_excel('data_job2.xlsx')

# %%
column = 'C'
# data2 = data2.sort_values(column).reset_index(drop=True)
names = data2['models']
values = data2[column]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xticks(rotation='vertical')

for i in range(0, len(names)):
    plt.barh(names[i], values[i], color=bar_colors[i])
#plt.title("JOB Inference Time")
plt.ylabel("Model")
plt.xlabel("Inference Time (μs)")
# fig.subplots_adjust(bottom=.5)
#plt.legend(names, loc=0, frameon=True)
fig.savefig('JOB-Inference Time.png', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# # Model Size

# %% [markdown]
# ## TPC-DS

# %%
data2 = pd.read_excel('book2.xlsx')

# %%
column = 'D'
# data2 = data2.sort_values(column).reset_index(drop=True)
names = data2['models']
values = data2[column]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xticks(rotation='vertical')

for i in range(0, len(names)):
    plt.barh(names[i], values[i], color=bar_colors[i])
#plt.title("TPCDS Model Size")
plt.ylabel("Modes")
plt.xlabel("Model Size(KB)")
# fig.subplots_adjust(bottom=.5)
#plt.legend(names, loc=0, frameon=True)
fig.savefig('TPCDS-Model Size.png', bbox_inches='tight', dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1v/zdszy15n595bb2xxfx_p9bhw0000gn/T/ipykernel_6149/3547054869.py in <module>
#       1 column = 'D'
#       2 # data2 = data2.sort_values(column).reset_index(drop=True)
# ----> 3 names = data2['models']
#       4 values = data2[column]
#       5
#
# NameError: name 'data2' is not defined

# %% [markdown]
# ## JOB

# %%
data2 = pd.read_excel('data_job2.xlsx')

# %%
column = 'D'
# data2 = data2.sort_values(column).reset_index(drop=True)
names = data2['models']
values = data2[column]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xticks(rotation='vertical')

for i in range(0, len(names)):
    plt.barh(names[i], values[i], color=bar_colors[i])
#plt.title("JOB Model Size")
plt.ylabel("Model")
plt.xlabel("Model Size(KB)")
# fig.subplots_adjust(bottom=.5)
#plt.legend(names, loc=0, frameon=True)
fig.savefig('JOB-Model Size.png', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# # TPCDS - REST

# %%
data2 = pd.read_excel('book2.xlsx')

# %%
column = 'B'
# data2 = data2.sort_values(column).reset_index(drop=True)
names = data2['models']
values = data2[column]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xticks(rotation='vertical')

for i in range(0, len(names) - 1):
    plt.barh(names[i], values[i], color=bar_colors[i])
plt.title("TPCDS Training Time")
plt.ylabel("Models")
plt.xlabel("Training Time(ms)")
# fig.subplots_adjust(bottom=.5)
#plt.legend(names, loc=0, frameon=True)
fig.savefig('tpcds-time.jpg', )
plt.show()

# %%
column = 'C'
# data2 = data2.sort_values(column).reset_index(drop=True)
names = data2['models']
values = data2[column]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xticks(rotation='vertical')

for i in range(0, len(names) - 1):
    plt.barh(names[i], values[i], color=bar_colors[i])
plt.title("TPCDS Inference Time")
plt.ylabel("Models")
plt.xlabel("Inference Time (μs)")
# fig.subplots_adjust(bottom=.5)
#plt.legend(names, loc=0, frameon=True)
fig.savefig('tpcds-inference.jpg')
plt.show()

# %%
column = 'D'
# data2 = data2.sort_values(column).reset_index(drop=True)
names = data2['models']
values = data2[column]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xticks(rotation='vertical')

for i in range(0, len(names) - 1):
    plt.barh(names[i], values[i], color=bar_colors[i])
plt.title("TPCDS Model Size")
plt.ylabel("Models")
plt.xlabel("Model Size(KB)")
# fig.subplots_adjust(bottom=.5)
#plt.legend(names, loc=0, frameon=True)
fig.savefig('tpcds-size.jpg')
plt.show()

# %% [markdown]
# # JOB

# %%
data = pd.read_excel('data_job.xlsx')

# %%
data2 = pd.read_excel('data_job2.xlsx')

# %%
column = 'A'
# data = data.sort_values(column).reset_index(drop=True)
names = data['models']
values = data[column]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xticks(rotation='vertical')

for i in range(0, len(names) - 1):
    plt.barh(names[i], RMSE[i], color=bar_colors[i])
#plt.title("JOB RMSE Error")
plt.ylabel("Model")
plt.xlabel("RMSE Error (MB)")
# fig.subplots_adjust(bottom=.5)
#plt.legend(names, loc=0, frameon=True)
fig.savefig('JOB-RMSE Error.png', bbox_inches='tight')
plt.show()

# %%
column = 'B'
# data2 = data2.sort_values(column).reset_index(drop=True)
names = data2['models']
values = data2[column]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xticks(rotation='vertical')

for i in range(0, len(names) - 1):
    plt.barh(names[i], values[i], color=bar_colors[i])
plt.title("JOB Training Time")
plt.ylabel("Models")
plt.xlabel("Training Time(ms)")
# fig.subplots_adjust(bottom=.5)
#plt.legend(names, loc=0, frameon=True)
fig.savefig('job-training.jpg')
plt.show()

# %%
column = 'C'
# data2 = data2.sort_values(column).reset_index(drop=True)
names = data2['models']
values = data2[column]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xticks(rotation='vertical')

for i in range(0, len(names) - 1):
    plt.barh(names[i], values[i], color=bar_colors[i])
plt.title("JOB Inference Time")
plt.ylabel("Models")
plt.xlabel("Inference Time (μs)")
# fig.subplots_adjust(bottom=.5)
#plt.legend(names, loc=0, frameon=True)
fig.savefig('job-inference.jpg')
plt.show()

# %%
column = 'D'
# data2 = data2.sort_values(column).reset_index(drop=True)
names = data2['models']
values = data2[column]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xticks(rotation='vertical')

for i in range(0, len(names) - 1):
    plt.barh(names[i], values[i], color=bar_colors[i])
plt.title("JOB Model Size")
plt.ylabel("Models")
plt.xlabel("Model Size(KB)")
# fig.subplots_adjust(bottom=.5)
#plt.legend(names, loc=0, frameon=True)
fig.savefig('job-size.jpg')
plt.show()

# %%
other
